# %%
from ROOT import TFile, TProfile, TCanvas, TH1D
import numpy as np
import matplotlib.pyplot as plt

c1=TCanvas("Calo Plots", "CaloPlots", 800, 600)
c1.Divide(2,1)
iterat=1
maxum=2

#runNumber=1571906107
runNumbers = ["1571906107", "1571906358"]
caloNumbers = []
caloMeans = []
numbervalues=0

for run in runNumbers:
    c1.cd(iterat)
    importFile = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/" + str(run) + ".root", "READ")
    RAWdata=importFile.Get("RAWdata")
    tProf=TProfile("name", "title", 5, 0.5, 5.5)
    caloPlace={5:1, 1:2, 2:3, 3:4, 4:5}
    for event in RAWdata:
        for i in [5, 1, 2, 3, 4]:
            value = getattr(event, "QDC0_ch"+str(i))
            if value>200:
                tProf.Fill(caloPlace[i], value)
            if i==1:
                caloNumbers +=[value]
                numbervalues+=1
    tProf.DrawCopy("colz")
    caloMeans +=[np.sum(caloNumbers)/numbervalues]
    caloNumbers = []
    numbervalues=0
    iterat+=1
    if iterat>maxum:
        break
        
c1.Draw()
print(caloMeans)
caloConstants = []
caloConstants += [caloMeans[0]/3]
caloConstants += [caloMeans[1]/5]
print(caloConstants)

arrayGeV=[3,5]
plt.plot(arrayGeV, caloConstants)
plt.show()
fit = np.polyfit(arrayGeV, caloConstants, 2)
eq = np.poly1d(fit)
print(eq(4))

# %%
from ROOT import TFile, TProfile, TCanvas, TH1D
import numpy as np

c1=TCanvas("Calo Plots", "CaloPlots", 800, 600)
c1.Divide(2,1)
iterat=1
maxum=2

#runNumber=1571906107
runNumbers = ["1571906955", "1571906677"]
caloNumbers = []
caloMeans = []
numbervalues=0

for run in runNumbers:
    c1.cd(iterat)
    importFile = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/" + str(run) + ".root", "READ")
    RAWdata=importFile.Get("RAWdata")
    tProf=TProfile("name", "title", 5, 0.5, 5.5)
    caloPlace={5:1, 1:2, 2:3, 3:4, 4:5}
    for event in RAWdata:
        for i in [5, 1, 2, 3, 4]:
            value = getattr(event, "QDC0_ch"+str(i))
            if value>200:
                tProf.Fill(caloPlace[i], value)
            if i==2:
                caloNumbers +=[value]
                numbervalues+=1
    tProf.DrawCopy("colz")
    caloMeans +=[np.sum(caloNumbers)/numbervalues]
    caloNumbers = []
    numbervalues=0
    iterat+=1
    if iterat>maxum:
        break
        
c1.Draw()
print(caloMeans)
caloConstants = []
caloConstants += [caloMeans[0]/3]
caloConstants += [caloMeans[1]/5]
print(caloConstants)

# %%
from ROOT import TFile, TProfile, TCanvas, TH1D
import numpy as np

c1=TCanvas("Calo Plots", "CaloPlots", 800, 600)
c1.Divide(2,1)
iterat=1
maxum=2

#runNumber=1571906107
runNumbers = ["1571907163", "1571907343"]
caloNumbers = []
caloMeans = []
numbervalues=0

for run in runNumbers:
    c1.cd(iterat)
    importFile = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/" + str(run) + ".root", "READ")
    RAWdata=importFile.Get("RAWdata")
    tProf=TProfile("name", "title", 5, 0.5, 5.5)
    caloPlace={5:1, 1:2, 2:3, 3:4, 4:5}
    for event in RAWdata:
        for i in [5, 1, 2, 3, 4]:
            value = getattr(event, "QDC0_ch"+str(i))
            if value>200:
                tProf.Fill(caloPlace[i], value)
            if i==3:
                caloNumbers +=[value]
                numbervalues+=1
    tProf.DrawCopy("colz")
    caloMeans +=[np.sum(caloNumbers)/numbervalues]
    caloNumbers = []
    numbervalues=0
    iterat+=1
    if iterat>maxum:
        break
        
c1.Draw()
print(caloMeans)
caloConstants = []
caloConstants += [caloMeans[0]/3]
caloConstants += [caloMeans[1]/5]
print(caloConstants)

# %%
from ROOT import TFile, TProfile, TCanvas, TH1D
import numpy as np

c1=TCanvas("Calo Plots", "CaloPlots", 800, 600)
c1.Divide(2,1)
iterat=1
maxum=2

#runNumber=1571906107
runNumbers = ["1571907892", "1571907628"]
caloNumbers = []
caloMeans = []
numbervalues=0

for run in runNumbers:
    c1.cd(iterat)
    importFile = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/" + str(run) + ".root", "READ")
    RAWdata=importFile.Get("RAWdata")
    tProf=TProfile("name", "title", 5, 0.5, 5.5)
    caloPlace={5:1, 1:2, 2:3, 3:4, 4:5}
    for event in RAWdata:
        for i in [5, 1, 2, 3, 4]:
            value = getattr(event, "QDC0_ch"+str(i))
            if value>200:
                tProf.Fill(caloPlace[i], value)
            if i==4:
                caloNumbers +=[value]
                numbervalues+=1
    tProf.DrawCopy("colz")
    caloMeans +=[np.sum(caloNumbers)/numbervalues]
    caloNumbers = []
    numbervalues=0
    iterat+=1
    if iterat>maxum:
        break
        
c1.Draw()
print(caloMeans)
caloConstants = []
caloConstants += [caloMeans[0]/3]
caloConstants += [caloMeans[1]/5]
print(caloConstants)

# %%
from ROOT import TFile, TProfile, TCanvas, TH1D
import numpy as np

c1=TCanvas("Calo Plots", "CaloPlots", 800, 600)
c1.Divide(2,1)
iterat=1
maxum=2

#runNumber=1571906107
runNumbers = ["1571905775", "1571905465"]
caloNumbers = []
caloMeans = []
numbervalues=0

for run in runNumbers:
    c1.cd(iterat)
    importFile = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/" + str(run) + ".root", "READ")
    RAWdata=importFile.Get("RAWdata")
    tProf=TProfile("name", "title", 5, 0.5, 5.5)
    caloPlace={5:1, 1:2, 2:3, 3:4, 4:5}
    for event in RAWdata:
        for i in [5, 1, 2, 3, 4]:
            value = getattr(event, "QDC0_ch"+str(i))
            if value>200:
                tProf.Fill(caloPlace[i], value)
            if i==5:
                caloNumbers +=[value]
                numbervalues+=1
    tProf.DrawCopy("colz")
    caloMeans +=[np.sum(caloNumbers)/numbervalues]
    caloNumbers = []
    numbervalues=0
    iterat+=1
    if iterat>maxum:
        break
        
c1.Draw()
print(caloMeans)
caloConstants = []
caloConstants += [caloMeans[0]/3]
caloConstants += [caloMeans[1]/5]
print(caloConstants)

# %%
from ROOT import TFile, TProfile, TCanvas, TH1D
import numpy as np

c1=TCanvas("Calo Plots", "CaloPlots", 800, 600)
c1.Divide(2,1)
iterat=1
maxum=2

#runNumber=1571906107
runNumbers = ["1572184203", "1572183834"]
caloNumbers = []
caloMeans = []
numbervalues=0

for run in runNumbers:
    c1.cd(iterat)
    importFile = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/" + str(run) + ".root", "READ")
    RAWdata=importFile.Get("RAWdata")
    tProf=TProfile("name", "title", 5, 0.5, 5.5)
    caloPlace={5:1, 1:2, 2:3, 3:4, 4:5}
    for event in RAWdata:
        for i in [5, 1, 2, 3, 4]:
            value = getattr(event, "QDC0_ch"+str(i))
            if value>200:
                tProf.Fill(caloPlace[i], value)
            if i==5:
                caloNumbers +=[value]
                numbervalues+=1
    tProf.DrawCopy("colz")
    caloMeans +=[np.sum(caloNumbers)/numbervalues]
    caloNumbers = []
    numbervalues=0
    iterat+=1
    if iterat>maxum:
        break
        
c1.Draw()
