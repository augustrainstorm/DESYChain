# %%
from ROOT import TFile
# Out:
# Welcome to JupyROOT 6.18/04

# %%
#I'm going to import one file initially and then run the same process on another set of files. 
importFile1 = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/1571909598.root", "READ")
importFile1.ls()
RAWdata=importFile1.Get("RAWdata")
# Out:
# TFile**		/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/1571909598.root
#  TFile*		/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/1571909598.root
#   KEY: TTree	RAWdata;1	BL4S RAW data tree
#   KEY: TTree	RECOdata;1	BL4S RECO data tree

# %%
for branch in RAWdata.GetListOfBranches():
    print(branch.GetName())
RAWdata.Print()
# Out:
# QDC0_ch0
# QDC0_ch1
# QDC0_ch2
# QDC0_ch3
# QDC0_ch4
# QDC0_ch5
# QDC0_ch6
# QDC0_ch7
# QDC0_ch8
# QDC0_ch9
# QDC0_ch10
# QDC0_ch11
# QDC0_ch12
# QDC0_ch13
# QDC0_ch14
# QDC0_ch15
# QDC0_ch16
# QDC0_ch17
# QDC0_ch18
# QDC0_ch19
# QDC0_ch20
# QDC0_ch21
# QDC0_ch22
# QDC0_ch23
# QDC0_ch24
# QDC0_ch25
# QDC0_ch26
# QDC0_ch27
# QDC0_ch28
# QDC0_ch29
# QDC0_ch30
# QDC0_ch31
# NTDC0_ch0
# TDC0_ch0
# NTDC0_ch1
# TDC0_ch1
# NTDC0_ch2
# TDC0_ch2
# NTDC0_ch3
# TDC0_ch3
# NTDC0_ch4
# TDC0_ch4
# NTDC0_ch5
# TDC0_ch5
# NTDC0_ch6
# TDC0_ch6
# NTDC0_ch7
# TDC0_ch7
# NTDC0_ch8
# TDC0_ch8
# NTDC0_ch9
# TDC0_ch9
# NTDC0_ch10
# TDC0_ch10
# NTDC0_ch11
# TDC0_ch11
# NTDC0_ch12
# TDC0_ch12
# NTDC0_ch13
# TDC0_ch13
# NTDC0_ch14
# TDC0_ch14
# NTDC0_ch15
# TDC0_ch15
# NTDC0_ch16
# TDC0_ch16
# NTDC0_ch17
# TDC0_ch17
# NTDC0_ch18
# TDC0_ch18
# NTDC0_ch19
# TDC0_ch19
# NTDC0_ch20
# TDC0_ch20
# NTDC0_ch21
# TDC0_ch21
# NTDC0_ch22
# TDC0_ch22
# NTDC0_ch23
# TDC0_ch23
# NTDC0_ch24
# TDC0_ch24
# NTDC0_ch25
# ...

# %%
RAWdata.GetBranch("TDC0_ch0").GetEntries()
# Out:
# 170408

# %%
from ROOT import TCanvas, TH2D
import numpy as np
import matplotlib.pyplot as plt
from ROOT import TH1D, TF1, gPad , gStyle, TGraph, TGraphErrors, gROOT, TColor

c1=TCanvas("TDC0X", "TDCX", 1600, 1200)
c1.Divide(1,2)
TDCXHist = TH2D ("DWCX", "DWCX", 100, 0, 4100, 100, 2000, 3800)
RAWdata.Draw("TDC0_ch0:TDC0_ch1 >>DWCX")

c1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: TDC0X
# Warning in <TFile::Append>: Replacing existing TH1: DWCX (Potential memory leak).
