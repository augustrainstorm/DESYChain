# %%
import os, pandas as pd, numpy as np
import ROOT
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
sns.set()
# Out:
# Welcome to JupyROOT 6.20/06

# %%
align220 = ROOT.TFile('/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/1572087790.root')
align220.ls()
# Out:
# TFile**		/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/1572087790.root
#  TFile*		/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/1572087790.root
#   KEY: TTree	RAWdata;1	BL4S RAW data tree
#   KEY: TTree	RECOdata;1	BL4S RECO data tree

# %%
reco_tree = align220.Get('RECOdata')
reco_tree.Print()
# Out:
# ******************************************************************************
# *Tree    :RECOdata  : BL4S RECO data tree                                    *
# *Entries :   117364 : Total =        42230537 bytes  File  Size =   16889189 *
# *        :          : Tree compression factor =   2.50                       *
# ******************************************************************************
# *Br    0 :NChamber1_position :                                               *
# *         | UInt_t Number of entries in branch Chamber1_position             *
# *Entries :   117364 : Total  Size=     471473 bytes  File Size  =      45183 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  10.42     *
# *............................................................................*
# *Br    1 :Chamber1_position :                                                *
# *         | Double_t Local position of Chamber1 clusters in cm               *
# *Entries :   117364 : Total  Size=     689526 bytes  File Size  =     171895 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   4.00     *
# *............................................................................*
# *Br    2 :NChamber2_position :                                               *
# *         | UInt_t Number of entries in branch Chamber2_position             *
# *Entries :   117364 : Total  Size=     471473 bytes  File Size  =      50358 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.35     *
# *............................................................................*
# *Br    3 :Chamber2_position :                                                *
# *         | Double_t Local position of Chamber2 clusters in cm               *
# *Entries :   117364 : Total  Size=     759126 bytes  File Size  =     237202 *
# *Baskets :       39 : Basket Size=      32000 bytes  Compression=   3.19     *
# *............................................................................*
# *Br    4 :NChamber3_position :                                               *
# *         | UInt_t Number of entries in branch Chamber3_position             *
# *Entries :   117364 : Total  Size=     471473 bytes  File Size  =      36978 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  12.73     *
# *............................................................................*
# *Br    5 :Chamber3_position :                                                *
# *         | Double_t Local position of Chamber3 clusters in cm               *
# *Entries :   117364 : Total  Size=     715550 bytes  File Size  =     166864 *
# *Baskets :       37 : Basket Size=      32000 bytes  Compression=   4.28     *
# *............................................................................*
# *Br    6 :NMimosa0_xPosition :                                               *
# *         | UInt_t Number of entries in branch Mimosa0_xPosition             *
# *Entries :   117364 : Total  Size=     471473 bytes  File Size  =      97362 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   4.84     *
# *............................................................................*
# *Br    7 :Mimosa0_xPosition :                                                *
# *         | Double_t Local position in x-axis of Mimosa0 clusters in cm      *
# *Entries :   117364 : Total  Size=    5376327 bytes  File Size  =    2410015 *
# *Baskets :      183 : Basket Size=      32000 bytes  Compression=   2.23     *
# *............................................................................*
# *Br    8 :NMimosa0_yPosition :                                               *
# *         | UInt_t Number of entries in branch Mimosa0_yPosition             *
# *Entries :   117364 : Total  Size=     471473 bytes  File Size  =      97362 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   4.84     *
# *............................................................................*
# *Br    9 :Mimosa0_yPosition :                                                *
# *         | Double_t Local position in y-axis of Mimosa0 clusters in cm      *
# *Entries :   117364 : Total  Size=    5376327 bytes  File Size  =    2298675 *
# *Baskets :      183 : Basket Size=      32000 bytes  Compression=   2.34     *
# *............................................................................*
# *Br   10 :NMimosa1_xPosition :                                               *
# *         | UInt_t Number of entries in branch Mimosa1_xPosition             *
# *Entries :   117364 : Total  Size=     471473 bytes  File Size  =      92726 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   5.08     *
# *............................................................................*
# *Br   11 :Mimosa1_xPosition :                                                *
# *         | Double_t Local position in x-axis of Mimosa1 clusters in cm      *
# *Entries :   117364 : Total  Size=    4199603 bytes  File Size  =    1954379 *
# *Baskets :      146 : Basket Size=      32000 bytes  Compression=   2.15     *
# *............................................................................*
# *Br   12 :NMimosa1_yPosition :                                               *
# *         | UInt_t Number of entries in branch Mimosa1_yPosition             *
# *Entries :   117364 : Total  Size=     471473 bytes  File Size  =      92726 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   5.08     *
# *............................................................................*
# *Br   13 :Mimosa1_yPosition :                                                *
# *         | Double_t Local position in y-axis of Mimosa1 clusters in cm      *
# *Entries :   117364 : Total  Size=    4199603 bytes  File Size  =    1902692 *
# *Baskets :      146 : Basket Size=      32000 bytes  Compression=   2.21     *
# *............................................................................*
# *Br   14 :NMimosa2_xPosition :                                               *
# *         | UInt_t Number of entries in branch Mimosa2_xPosition             *
# *Entries :   117364 : Total  Size=     471473 bytes  File Size  =      91620 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   5.14     *
# *............................................................................*
# *Br   15 :Mimosa2_xPosition :                                                *
# *         | Double_t Local position in x-axis of Mimosa2 clusters in cm      *
# *Entries :   117364 : Total  Size=    4925015 bytes  File Size  =    2110295 *
# *Baskets :      169 : Basket Size=      32000 bytes  Compression=   2.33     *
# *............................................................................*
# *Br   16 :NMimosa2_yPosition :                                               *
# *         | UInt_t Number of entries in branch Mimosa2_yPosition             *
# *Entries :   117364 : Total  Size=     471473 bytes  File Size  =      91620 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   5.14     *
# *............................................................................*
# *Br   17 :Mimosa2_yPosition :                                                *
# *         | Double_t Local position in y-axis of Mimosa2 clusters in cm      *
# *Entries :   117364 : Total  Size=    4925015 bytes  File Size  =    2043026 *
# *Baskets :      169 : Basket Size=      32000 bytes  Compression=   2.41     *
# *............................................................................*
# *Br   18 :NDWC0_xTime : UInt_t Number of entries in branch DWC0_xTime        *
# *Entries :   117364 : Total  Size=     471340 bytes  File Size  =      48883 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.63     *
# *............................................................................*
# *Br   19 :DWC0_xTime :                                                       *
# *         | Double_t Time difference of hits along x-axis of DWC0 in ns      *
# *Entries :   117364 : Total  Size=    1228106 bytes  File Size  =     547245 *
# *Baskets :       53 : Basket Size=      32000 bytes  Compression=   2.24     *
# *............................................................................*
# *Br   20 :NDWC0_yTime : UInt_t Number of entries in branch DWC0_yTime        *
# *Entries :   117364 : Total  Size=     471340 bytes  File Size  =      48777 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.65     *
# *............................................................................*
# *Br   21 :DWC0_yTime :                                                       *
# *         | Double_t Time difference of hits along y-axis of DWC0 in ns      *
# *Entries :   117364 : Total  Size=    1220986 bytes  File Size  =     521781 *
# *Baskets :       53 : Basket Size=      32000 bytes  Compression=   2.34     *
# *............................................................................*
# *Br   22 :NDWC0_xPosition : UInt_t Number of entries in branch DWC0_xPosition*
# *Entries :   117364 : Total  Size=     471416 bytes  File Size  =      51264 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.18     *
# *............................................................................*
# *Br   23 :DWC0_xPosition :                                                   *
# *         | Double_t Local position in x-axis of DWC0 hits in cm             *
# *Entries :   117364 : Total  Size=    1243688 bytes  File Size  =     814725 *
# *Baskets :       54 : Basket Size=      32000 bytes  Compression=   1.52     *
# *............................................................................*
# *Br   24 :NDWC0_yPosition : UInt_t Number of entries in branch DWC0_yPosition*
# *Entries :   117364 : Total  Size=     471416 bytes  File Size  =      51264 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.18     *
# *............................................................................*
# *Br   25 :DWC0_yPosition :                                                   *
# *         | Double_t Local position in y-axis of DWC0 hits in cm             *
# *Entries :   117364 : Total  Size=    1243688 bytes  File Size  =     798335 *
# *Baskets :       54 : Basket Size=      32000 bytes  Compression=   1.56     *
# *............................................................................*

# %%
raw_tree = align220.Get('RAWdata')
raw_tree.Print()
# Out:
# ******************************************************************************
# *Tree    :RAWdata   : BL4S RAW data tree                                     *
# *Entries :   117364 : Total =        95962222 bytes  File  Size =   19691878 *
# *        :          : Tree compression factor =   4.88                       *
# ******************************************************************************
# *Br    0 :QDC0_ch0  : QDC0_ch0/i                                             *
# *Entries :   117364 : Total  Size=     471243 bytes  File Size  =     146516 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   3.21     *
# *............................................................................*
# *Br    1 :QDC0_ch1  : QDC0_ch1/i                                             *
# *Entries :   117364 : Total  Size=     471243 bytes  File Size  =     157460 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   2.99     *
# *............................................................................*
# *Br    2 :QDC0_ch2  : QDC0_ch2/i                                             *
# *Entries :   117364 : Total  Size=     471243 bytes  File Size  =     210724 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   2.23     *
# *............................................................................*
# *Br    3 :QDC0_ch3  : QDC0_ch3/i                                             *
# *Entries :   117364 : Total  Size=     471243 bytes  File Size  =     255646 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.84     *
# *............................................................................*
# *Br    4 :QDC0_ch4  : QDC0_ch4/i                                             *
# *Entries :   117364 : Total  Size=     471243 bytes  File Size  =     252744 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   1.86     *
# *............................................................................*
# *Br    5 :QDC0_ch5  : QDC0_ch5/i                                             *
# *Entries :   117364 : Total  Size=     471243 bytes  File Size  =     149582 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   3.15     *
# *............................................................................*
# *Br    6 :QDC0_ch6  : QDC0_ch6/i                                             *
# *Entries :   117364 : Total  Size=     471243 bytes  File Size  =      58388 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   8.06     *
# *............................................................................*
# *Br    7 :QDC0_ch7  : QDC0_ch7/i                                             *
# *Entries :   117364 : Total  Size=     471243 bytes  File Size  =      37808 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  12.45     *
# *............................................................................*
# *Br    8 :QDC0_ch8  : QDC0_ch8/i                                             *
# *Entries :   117364 : Total  Size=     471243 bytes  File Size  =      51531 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.13     *
# *............................................................................*
# *Br    9 :QDC0_ch9  : QDC0_ch9/i                                             *
# *Entries :   117364 : Total  Size=     471243 bytes  File Size  =      34992 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  13.45     *
# *............................................................................*
# *Br   10 :QDC0_ch10 : QDC0_ch10/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      46554 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  10.11     *
# *............................................................................*
# *Br   11 :QDC0_ch11 : QDC0_ch11/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      38613 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  12.19     *
# *............................................................................*
# *Br   12 :QDC0_ch12 : QDC0_ch12/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      49099 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.59     *
# *............................................................................*
# *Br   13 :QDC0_ch13 : QDC0_ch13/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      43238 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  10.88     *
# *............................................................................*
# *Br   14 :QDC0_ch14 : QDC0_ch14/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      48105 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.78     *
# *............................................................................*
# *Br   15 :QDC0_ch15 : QDC0_ch15/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      38265 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  12.30     *
# *............................................................................*
# *Br   16 :QDC0_ch16 : QDC0_ch16/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      23923 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  19.67     *
# *............................................................................*
# *Br   17 :QDC0_ch17 : QDC0_ch17/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      45012 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  10.46     *
# *............................................................................*
# *Br   18 :QDC0_ch18 : QDC0_ch18/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      46847 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  10.05     *
# *............................................................................*
# *Br   19 :QDC0_ch19 : QDC0_ch19/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      45048 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  10.45     *
# *............................................................................*
# *Br   20 :QDC0_ch20 : QDC0_ch20/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      28783 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  16.35     *
# *............................................................................*
# *Br   21 :QDC0_ch21 : QDC0_ch21/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      48911 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.62     *
# *............................................................................*
# *Br   22 :QDC0_ch22 : QDC0_ch22/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      48907 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.62     *
# *............................................................................*
# *Br   23 :QDC0_ch23 : QDC0_ch23/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      37244 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  12.64     *
# *............................................................................*
# *Br   24 :QDC0_ch24 : QDC0_ch24/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      45434 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  10.36     *
# *............................................................................*
# *Br   25 :QDC0_ch25 : QDC0_ch25/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      39378 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  11.95     *
# *............................................................................*
# *Br   26 :QDC0_ch26 : QDC0_ch26/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      21558 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  21.83     *
# *............................................................................*
# *Br   27 :QDC0_ch27 : QDC0_ch27/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      42775 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  11.00     *
# *............................................................................*
# *Br   28 :QDC0_ch28 : QDC0_ch28/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      35795 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  13.15     *
# *............................................................................*
# *Br   29 :QDC0_ch29 : QDC0_ch29/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      27483 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  17.12     *
# *............................................................................*
# *Br   30 :QDC0_ch30 : QDC0_ch30/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      40833 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  11.53     *
# *............................................................................*
# *Br   31 :QDC0_ch31 : QDC0_ch31/i                                            *
# *Entries :   117364 : Total  Size=     471262 bytes  File Size  =      39875 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  11.80     *
# *............................................................................*
# *Br   32 :NTDC0_ch0 : UInt_t Number of entries in branch TDC0_ch0            *
# *Entries :   117364 : Total  Size=     471287 bytes  File Size  =      43806 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  10.74     *
# *............................................................................*
# *Br   33 :TDC0_ch0  : TDC0_ch0[NTDC0_ch0]/i                                  *
# *Entries :   117364 : Total  Size=     870521 bytes  File Size  =     393990 *
# *Baskets :       42 : Basket Size=      32000 bytes  Compression=   2.21     *
# *............................................................................*
# *Br   34 :NTDC0_ch1 : UInt_t Number of entries in branch TDC0_ch1            *
# *Entries :   117364 : Total  Size=     471287 bytes  File Size  =      43565 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  10.80     *
# *............................................................................*
# *Br   35 :TDC0_ch1  : TDC0_ch1[NTDC0_ch1]/i                                  *
# *Entries :   117364 : Total  Size=     869209 bytes  File Size  =     393579 *
# *Baskets :       42 : Basket Size=      32000 bytes  Compression=   2.21     *
# *............................................................................*
# *Br   36 :NTDC0_ch2 : UInt_t Number of entries in branch TDC0_ch2            *
# *Entries :   117364 : Total  Size=     471287 bytes  File Size  =      46736 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  10.07     *
# *............................................................................*
# *Br   37 :TDC0_ch2  : TDC0_ch2[NTDC0_ch2]/i                                  *
# *Entries :   117364 : Total  Size=     843387 bytes  File Size  =     377069 *
# *Baskets :       41 : Basket Size=      32000 bytes  Compression=   2.23     *
# *............................................................................*
# *Br   38 :NTDC0_ch3 : UInt_t Number of entries in branch TDC0_ch3            *
# *Entries :   117364 : Total  Size=     471287 bytes  File Size  =      47635 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.88     *
# *............................................................................*
# *Br   39 :TDC0_ch3  : TDC0_ch3[NTDC0_ch3]/i                                  *
# *Entries :   117364 : Total  Size=     853025 bytes  File Size  =     379982 *
# *Baskets :       42 : Basket Size=      32000 bytes  Compression=   2.24     *
# *............................................................................*
# *Br   40 :NTDC0_ch4 : UInt_t Number of entries in branch TDC0_ch4            *
# *Entries :   117364 : Total  Size=     471287 bytes  File Size  =       3724 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 126.38     *
# *............................................................................*
# *Br   41 :TDC0_ch4  : TDC0_ch4[NTDC0_ch4]/i                                  *
# *Entries :   117364 : Total  Size=     473053 bytes  File Size  =       5836 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.88     *
# *............................................................................*
# *Br   42 :NTDC0_ch5 : UInt_t Number of entries in branch TDC0_ch5            *
# *Entries :   117364 : Total  Size=     471287 bytes  File Size  =       3724 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 126.38     *
# *............................................................................*
# *Br   43 :TDC0_ch5  : TDC0_ch5[NTDC0_ch5]/i                                  *
# *Entries :   117364 : Total  Size=     473053 bytes  File Size  =       5836 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.88     *
# *............................................................................*
# *Br   44 :NTDC0_ch6 : UInt_t Number of entries in branch TDC0_ch6            *
# *Entries :   117364 : Total  Size=     471287 bytes  File Size  =       3724 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 126.38     *
# *............................................................................*
# *Br   45 :TDC0_ch6  : TDC0_ch6[NTDC0_ch6]/i                                  *
# *Entries :   117364 : Total  Size=     473053 bytes  File Size  =       5836 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.88     *
# *............................................................................*
# *Br   46 :NTDC0_ch7 : UInt_t Number of entries in branch TDC0_ch7            *
# *Entries :   117364 : Total  Size=     471287 bytes  File Size  =       3724 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 126.38     *
# *............................................................................*
# *Br   47 :TDC0_ch7  : TDC0_ch7[NTDC0_ch7]/i                                  *
# *Entries :   117364 : Total  Size=     473053 bytes  File Size  =       5836 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.88     *
# *............................................................................*
# *Br   48 :NTDC0_ch8 : UInt_t Number of entries in branch TDC0_ch8            *
# *Entries :   117364 : Total  Size=     471287 bytes  File Size  =       3724 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 126.38     *
# *............................................................................*
# *Br   49 :TDC0_ch8  : TDC0_ch8[NTDC0_ch8]/i                                  *
# *Entries :   117364 : Total  Size=     473053 bytes  File Size  =       5836 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.88     *
# *............................................................................*
# *Br   50 :NTDC0_ch9 : UInt_t Number of entries in branch TDC0_ch9            *
# *Entries :   117364 : Total  Size=     471287 bytes  File Size  =       3724 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 126.38     *
# *............................................................................*
# *Br   51 :TDC0_ch9  : TDC0_ch9[NTDC0_ch9]/i                                  *
# *Entries :   117364 : Total  Size=     473053 bytes  File Size  =       5836 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.88     *
# *............................................................................*
# *Br   52 :NTDC0_ch10 : UInt_t Number of entries in branch TDC0_ch10          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   53 :TDC0_ch10 : TDC0_ch10[NTDC0_ch10]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   54 :NTDC0_ch11 : UInt_t Number of entries in branch TDC0_ch11          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   55 :TDC0_ch11 : TDC0_ch11[NTDC0_ch11]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   56 :NTDC0_ch12 : UInt_t Number of entries in branch TDC0_ch12          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   57 :TDC0_ch12 : TDC0_ch12[NTDC0_ch12]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   58 :NTDC0_ch13 : UInt_t Number of entries in branch TDC0_ch13          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   59 :TDC0_ch13 : TDC0_ch13[NTDC0_ch13]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   60 :NTDC0_ch14 : UInt_t Number of entries in branch TDC0_ch14          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   61 :TDC0_ch14 : TDC0_ch14[NTDC0_ch14]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   62 :NTDC0_ch15 : UInt_t Number of entries in branch TDC0_ch15          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   63 :TDC0_ch15 : TDC0_ch15[NTDC0_ch15]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   64 :NTDC0_ch16 : UInt_t Number of entries in branch TDC0_ch16          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   65 :TDC0_ch16 : TDC0_ch16[NTDC0_ch16]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   66 :NTDC0_ch17 : UInt_t Number of entries in branch TDC0_ch17          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   67 :TDC0_ch17 : TDC0_ch17[NTDC0_ch17]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   68 :NTDC0_ch18 : UInt_t Number of entries in branch TDC0_ch18          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   69 :TDC0_ch18 : TDC0_ch18[NTDC0_ch18]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   70 :NTDC0_ch19 : UInt_t Number of entries in branch TDC0_ch19          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   71 :TDC0_ch19 : TDC0_ch19[NTDC0_ch19]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   72 :NTDC0_ch20 : UInt_t Number of entries in branch TDC0_ch20          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   73 :TDC0_ch20 : TDC0_ch20[NTDC0_ch20]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   74 :NTDC0_ch21 : UInt_t Number of entries in branch TDC0_ch21          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   75 :TDC0_ch21 : TDC0_ch21[NTDC0_ch21]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   76 :NTDC0_ch22 : UInt_t Number of entries in branch TDC0_ch22          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   77 :TDC0_ch22 : TDC0_ch22[NTDC0_ch22]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   78 :NTDC0_ch23 : UInt_t Number of entries in branch TDC0_ch23          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   79 :TDC0_ch23 : TDC0_ch23[NTDC0_ch23]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   80 :NTDC0_ch24 : UInt_t Number of entries in branch TDC0_ch24          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   81 :TDC0_ch24 : TDC0_ch24[NTDC0_ch24]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   82 :NTDC0_ch25 : UInt_t Number of entries in branch TDC0_ch25          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   83 :TDC0_ch25 : TDC0_ch25[NTDC0_ch25]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   84 :NTDC0_ch26 : UInt_t Number of entries in branch TDC0_ch26          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   85 :TDC0_ch26 : TDC0_ch26[NTDC0_ch26]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   86 :NTDC0_ch27 : UInt_t Number of entries in branch TDC0_ch27          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   87 :TDC0_ch27 : TDC0_ch27[NTDC0_ch27]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   88 :NTDC0_ch28 : UInt_t Number of entries in branch TDC0_ch28          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   89 :TDC0_ch28 : TDC0_ch28[NTDC0_ch28]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   90 :NTDC0_ch29 : UInt_t Number of entries in branch TDC0_ch29          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   91 :TDC0_ch29 : TDC0_ch29[NTDC0_ch29]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   92 :NTDC0_ch30 : UInt_t Number of entries in branch TDC0_ch30          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   93 :TDC0_ch30 : TDC0_ch30[NTDC0_ch30]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   94 :NTDC0_ch31 : UInt_t Number of entries in branch TDC0_ch31          *
# *Entries :   117364 : Total  Size=     471306 bytes  File Size  =       3739 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression= 125.88     *
# *............................................................................*
# *Br   95 :TDC0_ch31 : TDC0_ch31[NTDC0_ch31]/i                                *
# *Entries :   117364 : Total  Size=     473091 bytes  File Size  =       5865 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  80.49     *
# *............................................................................*
# *Br   96 :NMMFE8_04_hitChannel :                                             *
# *         | UInt_t Number of entries in branch MMFE8_04_hitChannel           *
# *Entries :   117364 : Total  Size=     471496 bytes  File Size  =      49712 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.47     *
# *............................................................................*
# *Br   97 :MMFE8_04_hitChannel : MMFE8_04_hitChannel[NMMFE8_04_hitChannel]/i  *
# *Entries :   117364 : Total  Size=     613927 bytes  File Size  =     121476 *
# *Baskets :       34 : Basket Size=      32000 bytes  Compression=   5.04     *
# *............................................................................*
# *Br   98 :NMMFE8_04_hitTDO :                                                 *
# *         | UInt_t Number of entries in branch MMFE8_04_hitTDO               *
# *Entries :   117364 : Total  Size=     471420 bytes  File Size  =      49665 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.48     *
# *............................................................................*
# *Br   99 :MMFE8_04_hitTDO : MMFE8_04_hitTDO[NMMFE8_04_hitTDO]/i              *
# *Entries :   117364 : Total  Size=     613759 bytes  File Size  =     128071 *
# *Baskets :       34 : Basket Size=      32000 bytes  Compression=   4.78     *
# *............................................................................*
# *Br  100 :NMMFE8_04_hitPDO :                                                 *
# *         | UInt_t Number of entries in branch MMFE8_04_hitPDO               *
# *Entries :   117364 : Total  Size=     471420 bytes  File Size  =      49665 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   9.48     *
# *............................................................................*
# *Br  101 :MMFE8_04_hitPDO : MMFE8_04_hitPDO[NMMFE8_04_hitPDO]/i              *
# *Entries :   117364 : Total  Size=     613759 bytes  File Size  =     144282 *
# *Baskets :       34 : Basket Size=      32000 bytes  Compression=   4.25     *
# *............................................................................*
# *Br  102 :NMMFE8_02_hitChannel :                                             *
# *         | UInt_t Number of entries in branch MMFE8_02_hitChannel           *
# *Entries :   117364 : Total  Size=     471496 bytes  File Size  =       8987 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  52.39     *
# *............................................................................*
# *Br  103 :MMFE8_02_hitChannel : MMFE8_02_hitChannel[NMMFE8_02_hitChannel]/i  *
# *Entries :   117364 : Total  Size=     482779 bytes  File Size  =      16471 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  29.24     *
# *............................................................................*
# *Br  104 :NMMFE8_02_hitTDO :                                                 *
# *         | UInt_t Number of entries in branch MMFE8_02_hitTDO               *
# *Entries :   117364 : Total  Size=     471420 bytes  File Size  =       8918 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  52.79     *
# *............................................................................*
# *Br  105 :MMFE8_02_hitTDO : MMFE8_02_hitTDO[NMMFE8_02_hitTDO]/i              *
# *Entries :   117364 : Total  Size=     482627 bytes  File Size  =      16439 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  29.29     *
# *............................................................................*
# *Br  106 :NMMFE8_02_hitPDO :                                                 *
# *         | UInt_t Number of entries in branch MMFE8_02_hitPDO               *
# *Entries :   117364 : Total  Size=     471420 bytes  File Size  =       8918 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  52.79     *
# *............................................................................*
# *Br  107 :MMFE8_02_hitPDO : MMFE8_02_hitPDO[NMMFE8_02_hitPDO]/i              *
# *Entries :   117364 : Total  Size=     482627 bytes  File Size  =      17276 *
# *Baskets :       30 : Basket Size=      32000 bytes  Compression=  27.87     *
# *............................................................................*
# *Br  108 :NMMFE8_03_hitChannel :                                             *
# *         | UInt_t Number of entries in branch MMFE8_03_hitChannel           *
# *Entries :   117364 : Total  Size=     471496 bytes  File Size  =      56427 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   8.34     *
# *............................................................................*
# *Br  109 :MMFE8_03_hitChannel : MMFE8_03_hitChannel[NMMFE8_03_hitChannel]/i  *
# *Entries :   117364 : Total  Size=     661673 bytes  File Size  =     153939 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   4.29     *
# *............................................................................*
# *Br  110 :NMMFE8_03_hitTDO :                                                 *
# *         | UInt_t Number of entries in branch MMFE8_03_hitTDO               *
# *Entries :   117364 : Total  Size=     471420 bytes  File Size  =      56382 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   8.35     *
# *............................................................................*
# *Br  111 :MMFE8_03_hitTDO : MMFE8_03_hitTDO[NMMFE8_03_hitTDO]/i              *
# *Entries :   117364 : Total  Size=     661497 bytes  File Size  =     159382 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   4.14     *
# *............................................................................*
# *Br  112 :NMMFE8_03_hitPDO :                                                 *
# *         | UInt_t Number of entries in branch MMFE8_03_hitPDO               *
# *Entries :   117364 : Total  Size=     471420 bytes  File Size  =      56382 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   8.35     *
# *............................................................................*
# *Br  113 :MMFE8_03_hitPDO : MMFE8_03_hitPDO[NMMFE8_03_hitPDO]/i              *
# *Entries :   117364 : Total  Size=     661497 bytes  File Size  =     176678 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   3.74     *
# *............................................................................*
# *Br  114 :NMMFE8_05_hitChannel :                                             *
# *         | UInt_t Number of entries in branch MMFE8_05_hitChannel           *
# *Entries :   117364 : Total  Size=     471496 bytes  File Size  =      39868 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  11.81     *
# *............................................................................*
# *Br  115 :MMFE8_05_hitChannel : MMFE8_05_hitChannel[NMMFE8_05_hitChannel]/i  *
# *Entries :   117364 : Total  Size=     874871 bytes  File Size  =     142469 *
# *Baskets :       42 : Basket Size=      32000 bytes  Compression=   6.13     *
# *............................................................................*
# *Br  116 :NMMFE8_05_hitTDO :                                                 *
# *         | UInt_t Number of entries in branch MMFE8_05_hitTDO               *
# *Entries :   117364 : Total  Size=     471420 bytes  File Size  =      39839 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  11.82     *
# *............................................................................*
# *Br  117 :MMFE8_05_hitTDO : MMFE8_05_hitTDO[NMMFE8_05_hitTDO]/i              *
# *Entries :   117364 : Total  Size=     874671 bytes  File Size  =     201210 *
# *Baskets :       42 : Basket Size=      32000 bytes  Compression=   4.34     *
# *............................................................................*
# *Br  118 :NMMFE8_05_hitPDO :                                                 *
# *         | UInt_t Number of entries in branch MMFE8_05_hitPDO               *
# *Entries :   117364 : Total  Size=     471420 bytes  File Size  =      39839 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=  11.82     *
# *............................................................................*
# *Br  119 :MMFE8_05_hitPDO : MMFE8_05_hitPDO[NMMFE8_05_hitPDO]/i              *
# *Entries :   117364 : Total  Size=     874671 bytes  File Size  =     221662 *
# *Baskets :       42 : Basket Size=      32000 bytes  Compression=   3.94     *
# *............................................................................*
# *Br  120 :NMimosa0_hitX : UInt_t Number of entries in branch Mimosa0_hitX    *
# *Entries :   117364 : Total  Size=     471363 bytes  File Size  =     125402 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   3.75     *
# *............................................................................*
# *Br  121 :Mimosa0_hitX : Mimosa0_hitX[NMimosa0_hitX]/i                       *
# *Entries :   117364 : Total  Size=    5723321 bytes  File Size  =    2350143 *
# *Baskets :      194 : Basket Size=      32000 bytes  Compression=   2.43     *
# *............................................................................*
# *Br  122 :NMimosa0_hitY : UInt_t Number of entries in branch Mimosa0_hitY    *
# *Entries :   117364 : Total  Size=     471363 bytes  File Size  =     125402 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   3.75     *
# *............................................................................*
# *Br  123 :Mimosa0_hitY : Mimosa0_hitY[NMimosa0_hitY]/i                       *
# *Entries :   117364 : Total  Size=    5723321 bytes  File Size  =    2229936 *
# *Baskets :      194 : Basket Size=      32000 bytes  Compression=   2.56     *
# *............................................................................*
# *Br  124 :NMimosa1_hitX : UInt_t Number of entries in branch Mimosa1_hitX    *
# *Entries :   117364 : Total  Size=     471363 bytes  File Size  =     123544 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   3.81     *
# *............................................................................*
# *Br  125 :Mimosa1_hitX : Mimosa1_hitX[NMimosa1_hitX]/i                       *
# *Entries :   117364 : Total  Size=    4997427 bytes  File Size  =    1980845 *
# *Baskets :      171 : Basket Size=      32000 bytes  Compression=   2.52     *
# *............................................................................*
# *Br  126 :NMimosa1_hitY : UInt_t Number of entries in branch Mimosa1_hitY    *
# *Entries :   117364 : Total  Size=     471363 bytes  File Size  =     123544 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   3.81     *
# *............................................................................*
# *Br  127 :Mimosa1_hitY : Mimosa1_hitY[NMimosa1_hitY]/i                       *
# *Entries :   117364 : Total  Size=    4997427 bytes  File Size  =    1886338 *
# *Baskets :      171 : Basket Size=      32000 bytes  Compression=   2.65     *
# *............................................................................*
# *Br  128 :NMimosa2_hitX : UInt_t Number of entries in branch Mimosa2_hitX    *
# *Entries :   117364 : Total  Size=     471363 bytes  File Size  =     122266 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   3.85     *
# *............................................................................*
# *Br  129 :Mimosa2_hitX : Mimosa2_hitX[NMimosa2_hitX]/i                       *
# *Entries :   117364 : Total  Size=    5647877 bytes  File Size  =    2191885 *
# *Baskets :      192 : Basket Size=      32000 bytes  Compression=   2.57     *
# *............................................................................*
# *Br  130 :NMimosa2_hitY : UInt_t Number of entries in branch Mimosa2_hitY    *
# *Entries :   117364 : Total  Size=     471363 bytes  File Size  =     122266 *
# *Baskets :       15 : Basket Size=      32000 bytes  Compression=   3.85     *
# *............................................................................*
# *Br  131 :Mimosa2_hitY : Mimosa2_hitY[NMimosa2_hitY]/i                       *
# *Entries :   117364 : Total  Size=    5647877 bytes  File Size  =    2080071 *
# *Baskets :      192 : Basket Size=      32000 bytes  Compression=   2.71     *
# *............................................................................*

# %%
counter = 0
for event in raw_tree:
    if event.QDC0_ch1 != 0:
        counter += 1
print(counter)
# Out:
# 117364

# %%
raw_tree.QDC0_ch1
# Out:
# 109

# %% [markdown]
# mimosa0x: 0.1601207569508606
# mimosa0y: -0.07063051201271404
# mimosa1x: -0.06461846057860465
# mimosa1y: -0.09961266679960284
# mimosa2x: 0.05954989388342275
# mimosa2y: -0.011716153431861982
#
#
# dwc0x: 0.17213498114834727
# dwc0y: 0.026641933809337017
# dwc1x: -0.2918359275218577
# dwc1y: 0.06619044044300657
#
# micromega2x: -0.5097737670903252
# micromega3y: -14.282806834735394

# %%
counter = 0
track_list = []

micom1 = -5.550002018703863
micom2 = 9.993977765153637
micom3 = -12.417674134453438
mm0x = 0.1280648674350116
mm0y = -0.07592221686215
mm1x = -0.06662978502391795
mm1y = -0.10666666168351381
mm2x = 0.024718181540863783
mm2y = -0.028878914372700584
dwc0x = 0.15218727915480154
dwc0y = -4.044614026327264

for event in reco_tree:
    
    if (len(event.Chamber1_position) == 0 or len(event.Chamber2_position) == 0 or 
        len(event.Mimosa0_xPosition) == 0 or len(event.Mimosa1_xPosition) == 0 or len(event.Mimosa2_xPosition) == 0):
        counter += 1
        continue
    
        
    track = []
    track.append(list(zip([x-mm0x for x in event.Mimosa0_xPosition], [x-mm0y for x in event.Mimosa0_yPosition])))
    track.append(list(zip([x-mm1x for x in event.Mimosa1_xPosition], [x-mm1y for x in event.Mimosa1_yPosition])))
    track.append(list(zip([x-mm2x for x in event.Mimosa2_xPosition], [x-mm2y for x in event.Mimosa2_yPosition])))
    
    track.append(list(zip([x-dwc0x for x in event.DWC0_xPosition], [x-dwc0y for x in event.DWC0_yPosition])))
    
    track.append(list([x-micom1 for x in event.Chamber1_position]))
    track.append(list([x-micom2 for x in event.Chamber2_position]))
    track.append(counter)
    track_list.append(track)
    
    counter += 1

# %%
len(track_list)
# Out:
# 8250

# %%
track_list[0][0]
# Out:
# [(0.6226551325649885, -0.15039778313785),
#  (-0.0645848674350116, 0.06856221686215)]

# %%
track_list[1][0]
# Out:
# [(0.6944151325649883, -0.38039778313785),
#  (-0.2553928674350116, -0.20486178313784997),
#  (-1.1621448674350117, 0.10720221686215001),
#  (0.47913513256498846, 0.19000221686215002)]

# %%
index = 4
fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(111)
ax1.scatter(*zip(*track_list[index][0]), c='r')
ax1.scatter(*zip(*track_list[index][1]), c='g')
ax1.scatter(*zip(*track_list[index][2]), c='b')
ax1.scatter(*zip(*track_list[index][3]), c='y')
    #ax1.scatter(*zip(*track_list[i][4]), c='black')
    #ax1.scatter(*zip(*track_list[i][5]), c='brown')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-018b89be3b4e> in <module>
#       5 ax1.scatter(*zip(*track_list[index][1]), c='g')
#       6 ax1.scatter(*zip(*track_list[index][2]), c='b')
# ----> 7 ax1.scatter(*zip(*track_list[index][3]), c='y')
#       8     #ax1.scatter(*zip(*track_list[i][4]), c='black')
#       9     #ax1.scatter(*zip(*track_list[i][5]), c='brown')
#
# /usr/local/lib64/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
index = 3
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(*zip(*track_list[index][0]), c='r')
ax1.scatter(*zip(*track_list[index][1]), c='g')
ax1.scatter(*zip(*track_list[index][2]), c='b')
ax1.scatter(*zip(*track_list[index][3]), c='y')
ax1.scatter(*zip(*track_list[index][4]), c='black')
print(track_list[0][5])
# Out:
# [(-0.6525, -16.3125)]

# %%
c = ROOT.TCanvas('c', 'c', 800, 600)
qdc1 = align145.Get('RECOdata')
qdc1.Draw('Mimosa1_yPosition', 'Mimosa1_xPosition>-.5&&Mimosa1_xPosition<.4')
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
