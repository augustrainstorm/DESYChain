# %%
from ROOT import TFile, TProfile, TCanvas, TH1D
import numpy as np

c1=TCanvas("Calo Plots", "CaloPlots", 800, 600)
c1.Divide(2,1)
iterat=1
maxum=2

#runNumber=1571906107
runNumbers = ["1571906107", "1571906358"]
caloNumbers = []
caloMeans = []
numbervalues=0

for run in runNumbers:
    c1.cd(iterat)
    importFile = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/" + str(run) + ".root", "READ")
    RAWdata=importFile.Get("RAWdata")
    tProf=TProfile("name", "title", 5, 0.5, 5.5)
    caloPlace={5:1, 1:2, 2:3, 3:4, 4:5}
    for event in RAWdata:
        for i in [5, 1, 2, 3, 4]:
            value = getattr(event, "QDC0_ch"+str(i))
            if value>200:
                tProf.Fill(caloPlace[i], value)
            if i==1:
                caloNumbers +=[value]
                numbervalues+=1
    tProf.DrawCopy("colz")
    caloMeans +=[np.sum(caloNumbers)/numbervalues]
    caloNumbers = []
    numbervalues=0
    iterat+=1
    if iterat>maxum:
        break
        
c1.Draw()
print(caloMeans)
caloConstants = []
caloConstants += [caloMeans[0]/3]
caloConstants += [caloMeans[1]/5]
print(caloConstants)
# Out:
# [1865.95820408456, 2731.433337467444]
# [621.9860680281867, 546.2866674934887]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Calo Plots

# %%
from ROOT import TFile, TProfile, TCanvas, TH1D
import numpy as np

c1=TCanvas("Calo Plots", "CaloPlots", 800, 600)
c1.Divide(2,1)
iterat=1
maxum=2

#runNumber=1571906107
runNumbers = ["1571906955", "1571906677"]
caloNumbers = []
caloMeans = []
numbervalues=0

for run in runNumbers:
    c1.cd(iterat)
    importFile = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/" + str(run) + ".root", "READ")
    RAWdata=importFile.Get("RAWdata")
    tProf=TProfile("name", "title", 5, 0.5, 5.5)
    caloPlace={5:1, 1:2, 2:3, 3:4, 4:5}
    for event in RAWdata:
        for i in [5, 1, 2, 3, 4]:
            value = getattr(event, "QDC0_ch"+str(i))
            if value>200:
                tProf.Fill(caloPlace[i], value)
            if i==2:
                caloNumbers +=[value]
                numbervalues+=1
    tProf.DrawCopy("colz")
    caloMeans +=[np.sum(caloNumbers)/numbervalues]
    caloNumbers = []
    numbervalues=0
    iterat+=1
    if iterat>maxum:
        break
        
c1.Draw()
print(caloMeans)
caloConstants = []
caloConstants += [caloMeans[0]/3]
caloConstants += [caloMeans[1]/5]
print(caloConstants)
# Out:
# [1851.1183835804773, 2627.067736229178]
# [617.0394611934925, 525.4135472458356]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Calo Plots

# %%
from ROOT import TFile, TProfile, TCanvas, TH1D
import numpy as np

c1=TCanvas("Calo Plots", "CaloPlots", 800, 600)
c1.Divide(2,1)
iterat=1
maxum=2

#runNumber=1571906107
runNumbers = ["1571907163", "1571907343"]
caloNumbers = []
caloMeans = []
numbervalues=0

for run in runNumbers:
    c1.cd(iterat)
    importFile = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/" + str(run) + ".root", "READ")
    RAWdata=importFile.Get("RAWdata")
    tProf=TProfile("name", "title", 5, 0.5, 5.5)
    caloPlace={5:1, 1:2, 2:3, 3:4, 4:5}
    for event in RAWdata:
        for i in [5, 1, 2, 3, 4]:
            value = getattr(event, "QDC0_ch"+str(i))
            if value>200:
                tProf.Fill(caloPlace[i], value)
            if i==3:
                caloNumbers +=[value]
                numbervalues+=1
    tProf.DrawCopy("colz")
    caloMeans +=[np.sum(caloNumbers)/numbervalues]
    caloNumbers = []
    numbervalues=0
    iterat+=1
    if iterat>maxum:
        break
        
c1.Draw()
print(caloMeans)
caloConstants = []
caloConstants += [caloMeans[0]/3]
caloConstants += [caloMeans[1]/5]
print(caloConstants)
# Out:
# [1887.8996841409369, 2715.6001184395586]
# [629.2998947136456, 543.1200236879117]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Calo Plots

# %%
from ROOT import TFile, TProfile, TCanvas, TH1D
import numpy as np

c1=TCanvas("Calo Plots", "CaloPlots", 800, 600)
c1.Divide(2,1)
iterat=1
maxum=2

#runNumber=1571906107
runNumbers = ["1571907892", "1571907628"]
caloNumbers = []
caloMeans = []
numbervalues=0

for run in runNumbers:
    c1.cd(iterat)
    importFile = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/" + str(run) + ".root", "READ")
    RAWdata=importFile.Get("RAWdata")
    tProf=TProfile("name", "title", 5, 0.5, 5.5)
    caloPlace={5:1, 1:2, 2:3, 3:4, 4:5}
    for event in RAWdata:
        for i in [5, 1, 2, 3, 4]:
            value = getattr(event, "QDC0_ch"+str(i))
            if value>200:
                tProf.Fill(caloPlace[i], value)
            if i==4:
                caloNumbers +=[value]
                numbervalues+=1
    tProf.DrawCopy("colz")
    caloMeans +=[np.sum(caloNumbers)/numbervalues]
    caloNumbers = []
    numbervalues=0
    iterat+=1
    if iterat>maxum:
        break
        
c1.Draw()
print(caloMeans)
caloConstants = []
caloConstants += [caloMeans[0]/3]
caloConstants += [caloMeans[1]/5]
print(caloConstants)
# Out:
# [1893.328096321856, 2733.3730386576253]
# [631.1093654406187, 546.674607731525]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Calo Plots

# %%
from ROOT import TFile, TProfile, TCanvas, TH1D
import numpy as np

c1=TCanvas("Calo Plots", "CaloPlots", 800, 600)
c1.Divide(2,1)
iterat=1
maxum=2

#runNumber=1571906107
runNumbers = ["1571905775", "1571905465"]
caloNumbers = []
caloMeans = []
numbervalues=0

for run in runNumbers:
    c1.cd(iterat)
    importFile = TFile("/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/" + str(run) + ".root", "READ")
    RAWdata=importFile.Get("RAWdata")
    tProf=TProfile("name", "title", 5, 0.5, 5.5)
    caloPlace={5:1, 1:2, 2:3, 3:4, 4:5}
    for event in RAWdata:
        for i in [5, 1, 2, 3, 4]:
            value = getattr(event, "QDC0_ch"+str(i))
            if value>200:
                tProf.Fill(caloPlace[i], value)
            if i==5:
                caloNumbers +=[value]
                numbervalues+=1
    tProf.DrawCopy("colz")
    caloMeans +=[np.sum(caloNumbers)/numbervalues]
    caloNumbers = []
    numbervalues=0
    iterat+=1
    if iterat>maxum:
        break
        
c1.Draw()
print(caloMeans)
caloConstants = []
caloConstants += [caloMeans[0]/3]
caloConstants += [caloMeans[1]/5]
print(caloConstants)
# Out:
# [1749.6545815561112, 2613.187713987992]
# [583.2181938520371, 522.6375427975984]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Calo Plots
