# %%
import os, pandas as pd, numpy as np
import ROOT
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
sns.set()
# Out:
# Welcome to JupyROOT 6.22/02

# %%
def create_track_list(tfile_tdaq):
    tfile_path = '/nfs/dust/fhlabs/group/BL4S/data/DESYChain/ConvertedData/' + str(tfile_tdaq) + '.root'
    data_run = ROOT.TFile(tfile_path)
    
    reco_tree = data_run.Get('RECOdata')
    
    umeg1 = -10.990702845870967
    umeg2 = -0.6230715372388512
    umeg3 = -14.775851810120347
    mm0x = 0.16200300477374738
    mm0y = -0.07188037854438818
    mm1x = -0.05921837693965215
    mm1y = -0.09816501082135087
    mm2x = 0.06484276816637088
    mm2y = -0.008958339912773188
    dwc0x = 0.16247327004382453
    dwc0y = -0.2269737482832313
    
    counter = 0
    track_list = []
    
    for event in reco_tree:

        if (len(event.Chamber1_position) == 0 or len(event.Chamber2_position) == 0 or 
            len(event.Mimosa0_xPosition) == 0 or len(event.Mimosa1_xPosition) == 0 or 
            len(event.Mimosa2_xPosition) == 0) or len(event.DWC0_xPosition) == 0 or
            len(event.Chamber3_position == 0):
            counter += 1
            continue


        track = []
        track.append(list(zip([x-mm0x for x in event.Mimosa0_xPosition], [x-mm0y for x in event.Mimosa0_yPosition])))
        track.append(list(zip([x-mm1x for x in event.Mimosa1_xPosition], [x-mm1y for x in event.Mimosa1_yPosition])))
        track.append(list(zip([x-mm2x for x in event.Mimosa2_xPosition], [x-mm2y for x in event.Mimosa2_yPosition])))

        track.append(list(zip([x-dwc0x for x in event.DWC0_xPosition], [x-dwc0y for x in event.DWC0_yPosition])))

        track.append(list([x-umeg1 for x in event.Chamber1_position]))
        track.append(list([x-umeg2 for x in event.Chamber2_position]))
        track.append(list([x-umeg3 for x in event.Chamber3_position]))
        track.append(counter)
        track_list.append(track)

        counter += 1
        
    return track_list
        
def display_event_scatterplot(track_list, event_index):
    fig = plt.figure(figsize=(8,6))
    ax1 = fig.add_subplot(111)
    ax1.scatter(*zip(*track_list[event_index][0]), c='r')
    ax1.scatter(*zip(*track_list[event_index][1]), c='g')
    ax1.scatter(*zip(*track_list[event_index][2]), c='b')
    ax1.scatter(*zip(*track_list[event_index][3]), c='y')
        #ax1.scatter(*zip(*track_list[i][4]), c='black')
        #ax1.scatter(*zip(*track_list[i][5]), c='brown')
# Out:
#   File "<ipython-input-85-9291b8f0d779>", line 26
#     len(event.Mimosa2_xPosition) == 0) or len(event.DWC0_xPosition) == 0 or
#                                                                            ^
# SyntaxError: invalid syntax

# %%
track_list = create_track_list(1572106243)
#1572100097
#1572100629
display_event_scatterplot(track_list, 0)
# Out:
# ...
# ...
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-1b28b9eb61a9> in <module>
# ----> 1 track_list = create_track_list(1572106243)
#       2 #1572100097
#       3 #1572100629
#       4 display_event_scatterplot(track_list, 0)
#
# <ipython-input-83-6943c24981a7> in create_track_list(tfile_tdaq)
#      21
#      22     for event in reco_tree:
# ---> 23         print(event.Chamber3_position)
#      24
#      25         if (len(event.Chamber1_position) == 0 or len(event.Chamber2_position) == 0 or
#
# /usr/local/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
# ...

# %%
event = 50
zs = np.array([[0,1,2]])
#print(zs.shape)
min_error = 100
for (x1, y1) in track_list[event][0]:
    for (x2, y2) in track_list[event][1]:
        for (x3, y3) in track_list[event][2]:
            X = np.array([[x1, y1, 0], [x2,y2,1], [x3,y3,2]])
            #print(X)
            X_mean = X.mean(axis=0)
            uu, dd, vv = np.linalg.svd(X - X_mean)
            #print(vv[0])
            linepts = vv[0] * np.mgrid[-7:7:2j][:, np.newaxis]
            linepts += X_mean
            direction = linepts[1]-linepts[0]
            z_t = (zs-linepts[0][2])/direction[2]
            points = np.concatenate((np.reshape(linepts[0, 0:2], (2,1)) + (z_t * np.reshape(direction[0:2], (2,1))), zs))
            error = np.mean(np.square(points.T - X))
            if error < min_error:
                best_fit = linepts
                best_points = np.array([[x1,x2,x3],[y1,y2,y3], [0,1,2]])
                best_pts = points
                print(np.sum(np.square(best_pts[0:2] - best_points[0:2]) / best_pts[0:2], axis=1))
                min_error = error
                
print(best_fit)
print(min_error)
print(best_points)
print(best_pts)
# Out:
# [0.05801859 0.01109839]
# [ 0.02103396 -2.60334591]
# [[-1.80737315 -0.07430758 -5.74394971]
#  [ 1.94156822  0.0740434   7.74394971]]
# 0.0003010348735022999
# [[-1.91443005e-01  2.88583769e-02  3.63877232e-01]
#  [-1.71962146e-03 -1.86749892e-02  1.99983399e-02]
#  [ 0.00000000e+00  1.00000000e+00  2.00000000e+00]]
# [[-2.10850962e-01  6.70975347e-02  3.45046031e-01]
#  [-1.11309110e-02 -1.32090240e-04  1.08667305e-02]
#  [ 0.00000000e+00  1.00000000e+00  2.00000000e+00]]

# %%
plt.plot(best_pts[2], best_pts[0])
plt.scatter(best_points[2], best_points[0])

# %%
x1 = [x[0] for x in track_list[event][0]]
x2 = [x[0] for x in track_list[event][1]]
x3 = [x[0] for x in track_list[event][2]]
x4 = [x[0] for x in track_list[event][3]]
#x5 = [x[0] for x in track_list[event][4]]
#x6 = [x[0] for x in track_list[event][5]]
for (a,b,c,d) in zip(x1,x2,x3,x4):
    plt.scatter(0, a)
    plt.scatter(1, b)
    plt.scatter(2, c)
    plt.scatter(3, d)
    #plt.scatter(4, e)
plt.plot(best_pts[2], best_pts[0])
plt.show()

# %%
print(track_list[event][4])
print(track_list[event][5])
# Out:
# [-5.006797154129032]
# [-10.254448304030989]

# %%
track_list[event][3]
# Out:
# [(0.2924903108405249, 3.6329434637916735)]

# %%
np.sum(np.square(best_pts[0:2] - best_points[0:2]) / best_pts[0:2], axis=1)
# Out:
# array([-0.0636019 , -0.07433269])

# %%
f = np.poly1d([5, 1])

x = np.linspace(0, 10, 30)
y = f(x) + 6*np.random.normal(size=len(x))
xn = np.linspace(0, 10, 200)

plt.plot(x, y, 'or')
plt.show()

# %%
a = np.vstack([x, np.ones(len(x))]).T
np.dot(np.linalg.inv(np.dot(a.T, a)), np.dot(a.T, y))
# Out:
# array([5.04172462, 0.32571098])

# %%
x = np.mgrid[-2:5:120j]
y = np.mgrid[1:9:120j]
z = np.mgrid[-5:3:120j]

data = np.concatenate((x[:, np.newaxis], 
                       y[:, np.newaxis], 
                       z[:, np.newaxis]), 
                      axis=1)

# Perturb with some Gaussian noise
data += np.random.normal(size=data.shape) * 0.4

# Calculate the mean of the points, i.e. the 'center' of the cloud
datamean = data.mean(axis=0)

# Do an SVD on the mean-centered data.
uu, dd, vv = np.linalg.svd(data - datamean)

# Now vv[0] contains the first principal component, i.e. the direction
# vector of the 'best fit' line in the least squares sense.

# Now generate some points along this best fit line, for plotting.

# I use -7, 7 since the spread of the data is roughly 14
# and we want it to have mean 0 (like the points we did
# the svd on). Also, it's a straight line, so we only need 2 points.
linepts = vv[0] * np.mgrid[-7:7:2j][:, np.newaxis]

# shift by the mean to get the line in the right place
linepts += datamean

# %%
data.shape
# Out:
# (120, 3)

# %%
data
# Out:
# array([[-2.50967320e+00,  1.66275445e+00, -5.11043858e+00],
#        [-2.18825127e+00,  1.05824454e+00, -5.18736597e+00],
#        [-1.53563646e+00,  1.21058742e+00, -5.39948235e+00],
#        [-2.13807727e+00,  9.08793530e-01, -5.08760887e+00],
#        [-1.17322721e+00,  1.95284144e+00, -4.48644969e+00],
#        [-1.44181256e+00,  1.51072269e+00, -4.75622415e+00],
#        [-1.20355119e+00,  1.59932845e+00, -4.59524905e+00],
#        [-1.89866698e+00,  1.46423684e+00, -5.06684998e+00],
#        [-1.06194880e+00,  1.33731318e+00, -4.90880031e+00],
#        [-1.57000210e+00,  1.78900253e+00, -3.28297783e+00],
#        [-1.83818439e+00,  1.91962879e+00, -4.49871100e+00],
#        [-1.40850441e+00,  1.07822732e+00, -4.55394221e+00],
#        [-1.41264134e+00,  1.42700470e+00, -4.10773363e+00],
#        [-1.12512513e+00,  1.61057173e+00, -4.44212355e+00],
#        [-6.56082097e-01,  1.83675770e+00, -3.75545901e+00],
#        [-1.19854507e+00,  1.74124827e+00, -3.43475137e+00],
# ...

# %%
vv[0]
# Out:
# array([0.53305307, 0.59356064, 0.60294294])

# %%
vv[0] * np.mgrid[-7:7:2j][:, np.newaxis]
# Out:
# array([[-3.7313715 , -4.15492449, -4.22060058],
#        [ 3.7313715 ,  4.15492449,  4.22060058]])

# %%
np.mgrid[0:2:2j][:, np.newaxis]
# Out:
# array([[0.],
#        [2.]])

# %%
np.array([0,1,2])+3
# Out:
# array([3, 4, 5])
